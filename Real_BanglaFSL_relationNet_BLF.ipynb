# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
try:
    import google.colab
    colab = True
except:
    colab = False

# %%
if colab is True:
    # Running in Google Colab
    # Clone the repo
    # !git clone https://github.com/sicara/easy-few-shot-learning
    # %cd easy-few-shot-learning
    # !pip install .
else:
    # Run locally
    # Ensure working directory is the project's root
    # Make sure easyfsl is installed!
    # %cd ..
# Out:
# Cloning into 'easy-few-shot-learning'...
# remote: Enumerating objects: 1188, done.
# remote: Counting objects: 100% (451/451), done.
# remote: Compressing objects: 100% (245/245), done.
# remote: Total 1188 (delta 285), reused 259 (delta 204), pack-reused 737
# Receiving objects: 100% (1188/1188), 2.33 MiB | 23.40 MiB/s, done.
# Resolving deltas: 100% (689/689), done.
# /content/easy-few-shot-learning
# Processing /content/easy-few-shot-learning
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from easyfsl==1.5.0) (3.7.1)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from easyfsl==1.5.0) (2.0.3)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from easyfsl==1.5.0) (2.3.0+cu121)
# Requirement already satisfied: torchvision>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from easyfsl==1.5.0) (0.18.0+cu121)
# Requirement already satisfied: tqdm>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from easyfsl==1.5.0) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->easyfsl==1.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->easyfsl==1.5.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.0->easyfsl==1.5.0) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.5.0->easyfsl==1.5.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->easyfsl==1.5.0) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->easyfsl==1.5.0)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->easyfsl==1.5.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->easyfsl==1.5.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->easyfsl==1.5.0) (1.3.0)
# Building wheels for collected packages: easyfsl
#   Building wheel for easyfsl (pyproject.toml) ... done
#   Created wheel for easyfsl: filename=easyfsl-1.5.0-py3-none-any.whl size=72952 sha256=4d9493d39447c7f86f82fddcd9763bf48aecc2bfef100dbfc4e5479f37d80b5f
#   Stored in directory: /root/.cache/pip/wheels/bb/79/35/1da2d9ffa9c9b6892f0cca4cda77ee397b97a1deda949049e2
# Successfully built easyfsl
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, easyfsl
# Successfully installed easyfsl-1.5.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %%
# !unzip /content/BasicFinalDatabase_FSL.zip -d /content/data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000060.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000061.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000062.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000063.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000064.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000065.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000066.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000067.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000068.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000069.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000070.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000071.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000072.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000073.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000074.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000075.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000076.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000077.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000078.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000079.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000080.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000081.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000082.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000083.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000084.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000085.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000086.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000087.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000088.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000089.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000090.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000091.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000092.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000093.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000094.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000095.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000096.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000097.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000098.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000099.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000100.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000101.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000102.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000103.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000104.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000105.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000106.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000107.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000108.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000109.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000110.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000111.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000112.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000113.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000114.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000115.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000116.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000117.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000118.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000119.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000120.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000121.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000122.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000123.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000124.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000125.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000126.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000127.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000128.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000129.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000130.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000131.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000132.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000133.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000134.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000135.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000136.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000137.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000138.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000139.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000140.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000141.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000142.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000143.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000144.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000145.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000146.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000147.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000148.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000149.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000150.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000151.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000152.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000153.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000154.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000155.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000156.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000157.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000158.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000159.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000160.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000161.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000162.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000163.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000164.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000165.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000166.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000167.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000168.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000169.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000170.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000171.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000172.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000173.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000174.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000175.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000176.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000177.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000178.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000179.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000180.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000181.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000182.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000183.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000184.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000185.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000186.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000187.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000188.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000189.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000190.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000191.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000192.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000193.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000194.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000195.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000196.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000197.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000198.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000199.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000200.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000201.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000202.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000203.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000204.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000205.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000206.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000207.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000208.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000209.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000210.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000211.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000212.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000213.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000214.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000215.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000216.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000217.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000218.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000219.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000220.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000221.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000222.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000223.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000224.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000225.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000226.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000227.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000228.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000229.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000230.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000231.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000232.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000233.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000234.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000235.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000236.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000237.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000238.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/201/bcc000239.bmp
#    creating: /content/data/BasicFinalDatabase_FSL/Train/202/
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000000.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000001.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000002.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000003.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000004.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000005.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000006.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000007.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000008.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000009.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000010.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000011.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000012.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000013.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000014.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000015.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000016.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000017.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000018.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000019.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000020.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000021.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000022.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000023.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000024.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000025.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000026.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000027.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000028.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000029.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000030.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000031.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000032.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000033.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000034.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000035.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000036.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000037.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000038.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000039.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000040.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000041.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000042.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000043.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000044.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000045.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000046.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000047.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000048.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000049.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000050.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000051.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000052.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000053.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000054.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000055.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000056.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000057.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000058.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000059.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000060.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000061.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000062.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000063.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000064.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000065.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000066.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000067.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000068.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000069.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000070.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000071.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000072.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000073.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000074.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000075.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000076.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000077.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000078.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000079.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000080.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000081.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000082.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000083.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000084.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000085.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000086.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000087.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000088.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000089.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000090.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000091.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000092.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000093.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000094.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000095.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000096.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000097.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000098.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000099.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000100.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000101.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000102.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000103.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000104.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000105.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000106.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000107.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000108.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000109.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000110.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000111.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000112.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000113.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000114.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000115.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000116.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000117.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000118.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000119.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000120.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000121.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000122.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000123.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000124.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000125.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000126.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000127.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000128.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000129.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000130.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000131.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000132.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000133.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000134.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000135.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000136.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000137.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000138.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000139.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000140.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000141.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000142.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000143.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000144.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000145.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000146.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000147.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000148.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000149.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000150.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000151.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000152.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000153.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000154.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000155.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000156.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000157.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000158.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000159.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000160.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000161.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000162.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000163.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000164.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000165.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000166.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000167.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000168.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000169.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000170.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000171.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000172.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000173.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000174.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000175.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000176.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000177.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000178.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000179.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000180.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000181.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000182.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000183.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000184.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000185.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000186.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000187.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000188.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000189.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000190.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000191.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000192.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000193.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000194.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000195.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000196.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000197.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000198.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000199.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000200.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000201.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000202.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000203.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000204.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000205.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000206.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000207.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000208.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000209.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000210.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000211.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000212.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000213.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000214.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000215.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000216.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000217.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000218.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000219.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000220.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000221.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000222.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000223.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000224.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000225.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000226.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000227.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000228.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000229.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000230.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000231.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000232.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000233.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000234.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000235.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000236.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000237.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000238.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/202/bcc000239.bmp
#    creating: /content/data/BasicFinalDatabase_FSL/Train/203/
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000000.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000001.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000002.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000003.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000004.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000005.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000006.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000007.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000008.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000009.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000010.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000011.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000012.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000013.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000014.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000015.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000016.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000017.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000018.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000019.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000020.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000021.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000022.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000023.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000024.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000025.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000026.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000027.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000028.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000029.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000030.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000031.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000032.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000033.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000034.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000035.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000036.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000037.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000038.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000039.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000040.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000041.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000042.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000043.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000044.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000045.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000046.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000047.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000048.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000049.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000050.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000051.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000052.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000053.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000054.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000055.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000056.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000057.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000058.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000059.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000060.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000061.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000062.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000063.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000064.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000065.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000066.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000067.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000068.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000069.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000070.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000071.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000072.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000073.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000074.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000075.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000076.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000077.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000078.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000079.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000080.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000081.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000082.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000083.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000084.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000085.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000086.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000087.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000088.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000089.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000090.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000091.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000092.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000093.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000094.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000095.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000096.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000097.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000098.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000099.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000100.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000101.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000102.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000103.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000104.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000105.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000106.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000107.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000108.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000109.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000110.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000111.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000112.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000113.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000114.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000115.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000116.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000117.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000118.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000119.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000120.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000121.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000122.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000123.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000124.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000125.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000126.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000127.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000128.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000129.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000130.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000131.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000132.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000133.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000134.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000135.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000136.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000137.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000138.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000139.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000140.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000141.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000142.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000143.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000144.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000145.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000146.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000147.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000148.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000149.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000150.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000151.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000152.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000153.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000154.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000155.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000156.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000157.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000158.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000159.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000160.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000161.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000162.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000163.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000164.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000165.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000166.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000167.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000168.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000169.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000170.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000171.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000172.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000173.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000174.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000175.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000176.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000177.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000178.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000179.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000180.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000181.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000182.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000183.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000184.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000185.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000186.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000187.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000188.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000189.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000190.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000191.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000192.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000193.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000194.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000195.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000196.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000197.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000198.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000199.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000200.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000201.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000202.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000203.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000204.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000205.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000206.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000207.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/203/bcc000208.bmp
# ...
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000030.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000031.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000032.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000033.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000034.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000035.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000036.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000037.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000038.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000039.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000040.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000041.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000042.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000043.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000044.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000045.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000046.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000047.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000048.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000049.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000050.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000051.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000052.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000053.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000054.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000055.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000056.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000057.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000058.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000059.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000060.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000061.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000062.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000063.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000064.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000065.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000066.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000067.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000068.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000069.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000070.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000071.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000072.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000073.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000074.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000075.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000076.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000077.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000078.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000079.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000080.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000081.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000082.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000083.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000084.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000085.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000086.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000087.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000088.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000089.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000090.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000091.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000092.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000093.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000094.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000095.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000096.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000097.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000098.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000099.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000100.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000101.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000102.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000103.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000104.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000105.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000106.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000107.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000108.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000109.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000110.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000111.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000112.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000113.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000114.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000115.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000116.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000117.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000118.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000119.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000120.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000121.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000122.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000123.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000124.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000125.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000126.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000127.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000128.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000129.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000130.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000131.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000132.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000133.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000134.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000135.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000136.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000137.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000138.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000139.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000140.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000141.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000142.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000143.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000144.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000145.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000146.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000147.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000148.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000149.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000150.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000151.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000152.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000153.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000154.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000155.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000156.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000157.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000158.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000159.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000160.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000161.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000162.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000163.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000164.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000165.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000166.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000167.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000168.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000169.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000170.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000171.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000172.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000173.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000174.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000175.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000176.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000177.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000178.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000179.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000180.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000181.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000182.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000183.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000184.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000185.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000186.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000187.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000188.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000189.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000190.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000191.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000192.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000193.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000194.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000195.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000196.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000197.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000198.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000199.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000200.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000201.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000202.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000203.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000204.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000205.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000206.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000207.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000208.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000209.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000210.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000211.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000212.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000213.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000214.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000215.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000216.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000217.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000218.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000219.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000220.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000221.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000222.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000223.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000224.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000225.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000226.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000227.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000228.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000229.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000230.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000231.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000232.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000233.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000234.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000235.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000236.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000237.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000238.bmp
#   inflating: /content/data/BasicFinalDatabase_FSL/Train/221/bcc000239.bmp

# %%
from pathlib import Path
import random
from statistics import mean

import numpy as np
import torch
from torch import nn
from tqdm import tqdm
import torchvision
import torch.utils.data

# %%
random_seed = 30
np.random.seed(random_seed)
torch.manual_seed(random_seed)
random.seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Episodic Training

# %%
n_way = 5
n_shot = 1
n_query = 10

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
n_workers = 0

# %%
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
import os

class BengaliCharactersDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}
        self.samples = []

        for class_name in self.classes:
            class_dir = os.path.join(root_dir, class_name)
            for img_file in os.listdir(class_dir):
                if img_file.endswith('.bmp'):
                    self.samples.append((os.path.join(class_dir, img_file), class_name))

        # Debug: Print the first few samples
        print("First few samples:")
        print(self.samples[:5])  # Adjust the number to print more or fewer samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label_str = self.samples[idx]
        image = Image.open(img_path).convert('RGB')

        # Convert label from string to integer
        label = self.class_to_idx[label_str]

        if self.transform:
            image = self.transform(image)

        return image, label

    def get_labels(self):
        return [label for _, label in self.samples]

# %%
image_size = 84  # Adjusted for ResNet, which typically expects larger input sizes

train_transforms = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

test_transforms = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
])

train_set = BengaliCharactersDataset(root_dir='/content/data/BasicFinalDatabase_FSL/Train', transform=train_transforms)
test_set = BengaliCharactersDataset(root_dir='/content/data/BasicFinalDatabase_FSL/Test', transform=test_transforms)
# Out:
# First few samples:
# [('/content/data/BasicFinalDatabase_FSL/Train/195/bcc000118.bmp', '195'), ('/content/data/BasicFinalDatabase_FSL/Train/195/bcc000133.bmp', '195'), ('/content/data/BasicFinalDatabase_FSL/Train/195/bcc000131.bmp', '195'), ('/content/data/BasicFinalDatabase_FSL/Train/195/bcc000180.bmp', '195'), ('/content/data/BasicFinalDatabase_FSL/Train/195/bcc000058.bmp', '195')]
# First few samples:
# [('/content/data/BasicFinalDatabase_FSL/Test/179/bcc000118.bmp', '179'), ('/content/data/BasicFinalDatabase_FSL/Test/179/bcc000133.bmp', '179'), ('/content/data/BasicFinalDatabase_FSL/Test/179/bcc000131.bmp', '179'), ('/content/data/BasicFinalDatabase_FSL/Test/179/bcc000180.bmp', '179'), ('/content/data/BasicFinalDatabase_FSL/Test/179/bcc000058.bmp', '179')]

# %%
from easyfsl.samplers import TaskSampler
from torch.utils.data import DataLoader


n_tasks_per_epoch = 500
n_validation_tasks = 100

# Directly use the test set for validation
val_set = test_set

train_set.get_labels = lambda: [
    instance[1] for instance in train_set
]

val_set.get_labels = lambda: [
    instance[1] for instance in val_set
]

# Those are special batch samplers that sample few-shot classification tasks with a pre-defined shape
train_sampler = TaskSampler(
    train_set, n_way=n_way, n_shot=n_shot, n_query=n_query, n_tasks=n_tasks_per_epoch
)
val_sampler = TaskSampler(
    val_set, n_way=n_way, n_shot=n_shot, n_query=n_query, n_tasks=n_validation_tasks
)

# Finally, the DataLoader. We customize the collate_fn so that batches are delivered
# in the shape: (support_images, support_labels, query_images, query_labels, class_ids)
train_loader = DataLoader(
    train_set,
    batch_sampler=train_sampler,
    num_workers=n_workers,
    pin_memory=True,
    collate_fn=train_sampler.episodic_collate_fn,
)
val_loader = DataLoader(
    val_set,
    batch_sampler=val_sampler,
    num_workers=n_workers,
    pin_memory=True,
    collate_fn=val_sampler.episodic_collate_fn,
)

print(len(train_set), len(val_set))
# Out:
# 9360 2640

# %%
#Only used this encoder for RelationNetworks few shot algorithm

class CNNEncoder(nn.Module):
    """docstring for ClassName"""
    def __init__(self):
        super(CNNEncoder, self).__init__()
        self.layer1 = nn.Sequential(
                        nn.Conv2d(3,64,kernel_size=3,padding=0),
                        nn.BatchNorm2d(64, momentum=1, affine=True),
                        nn.ReLU(),
                        nn.MaxPool2d(2))
        self.layer2 = nn.Sequential(
                        nn.Conv2d(64,64,kernel_size=3,padding=0),
                        nn.BatchNorm2d(64, momentum=1, affine=True),
                        nn.ReLU(),
                        nn.MaxPool2d(2))
        self.layer3 = nn.Sequential(
                        nn.Conv2d(64,64,kernel_size=3,padding=1),
                        nn.BatchNorm2d(64, momentum=1, affine=True),
                        nn.ReLU())
        self.layer4 = nn.Sequential(
                        nn.Conv2d(64,64,kernel_size=3,padding=1),
                        nn.BatchNorm2d(64, momentum=1, affine=True),
                        nn.ReLU())

    def forward(self,x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        #out = out.view(out.size(0),-1)
        return out # 64

from easyfsl.methods import RelationNetworks, FewShotClassifier

convolutional_network = CNNEncoder()
few_shot_classifier = RelationNetworks(convolutional_network,feature_dimension = 64).to(DEVICE)

# %%
from torch.optim import SGD, Optimizer
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.tensorboard import SummaryWriter


LOSS_FUNCTION = nn.CrossEntropyLoss()

n_epochs = 30
scheduler_milestones = [120, 160]
scheduler_gamma = 0.1
learning_rate = 1e-2
tb_logs_dir = Path(".")

train_optimizer = SGD(
    few_shot_classifier.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4
)
train_scheduler = MultiStepLR(
    train_optimizer,
    milestones=scheduler_milestones,
    gamma=scheduler_gamma,
)

tb_writer = SummaryWriter(log_dir=str(tb_logs_dir))

# %%
def training_epoch(
    model: FewShotClassifier, data_loader: DataLoader, optimizer: Optimizer
):
    all_loss = []
    model.train()
    with tqdm(
        enumerate(data_loader), total=len(data_loader), desc="Training"
    ) as tqdm_train:
        for episode_index, (
            support_images,
            support_labels,
            query_images,
            query_labels,
            _,
        ) in tqdm_train:
            optimizer.zero_grad()
            model.process_support_set(
                support_images.to(DEVICE), support_labels.to(DEVICE)
            )
            classification_scores = model(query_images.to(DEVICE))

            loss = LOSS_FUNCTION(classification_scores, query_labels.to(DEVICE))

            loss.backward()

            optimizer.step()

            all_loss.append(loss.item())

            tqdm_train.set_postfix(loss=mean(all_loss))

    return mean(all_loss)

# %%
from easyfsl.utils import evaluate


best_state = few_shot_classifier.state_dict()
best_validation_accuracy = 0.0
for epoch in range(n_epochs):
    print(f"Epoch {epoch}")
    average_loss = training_epoch(few_shot_classifier, train_loader, train_optimizer)
    validation_accuracy = evaluate(
        few_shot_classifier, val_loader, device=DEVICE, tqdm_prefix="Validation"
    )

    if validation_accuracy > best_validation_accuracy:
        best_validation_accuracy = validation_accuracy
        best_state = few_shot_classifier.state_dict()
        print("Ding ding ding! We found a new best model!")

    tb_writer.add_scalar("Train/loss", average_loss, epoch)
    tb_writer.add_scalar("Val/acc", validation_accuracy, epoch)

    # Warn the scheduler that we did an epoch
    # so it knows when to decrease the learning rate
    train_scheduler.step()

    if epoch % 1 == 0 : torch.save(best_state, '/content/drive/MyDrive/PatternRecognition-main/ML/Proto/real_1shot_5way_BanglaPrototypicalNetworks_BanglaLekha_Final.pth')
# Out:
# Epoch 0
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.89it/s, loss=1.3]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.69it/s, accuracy=0.614]
# Ding ding ding! We found a new best model!
# Epoch 1
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.63it/s, loss=1.17]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 21.96it/s, accuracy=0.65]
# Ding ding ding! We found a new best model!
# Epoch 2
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.12it/s, loss=1.13]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.39it/s, accuracy=0.649]
# Epoch 3
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.12it/s, loss=1.1]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 23.15it/s, accuracy=0.703]
# Ding ding ding! We found a new best model!
# Epoch 4
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.67it/s, loss=1.09]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.83it/s, accuracy=0.654]
# Epoch 5
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.91it/s, loss=1.08]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.28it/s, accuracy=0.671]
# Epoch 6
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.92it/s, loss=1.07]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.25it/s, accuracy=0.734]
# Ding ding ding! We found a new best model!
# Epoch 7
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.72it/s, loss=1.06]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 18.52it/s, accuracy=0.74]
# Ding ding ding! We found a new best model!
# Epoch 8
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.04it/s, loss=1.05]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 19.07it/s, accuracy=0.724]
# Epoch 9
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.15it/s, loss=1.04]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 18.86it/s, accuracy=0.753]
# Ding ding ding! We found a new best model!
# Epoch 10
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.22it/s, loss=1.05]
# Validation: 100%|██████████| 100/100 [00:06<00:00, 16.37it/s, accuracy=0.721]
# Epoch 11
# Training: 100%|██████████| 500/500 [00:34<00:00, 14.38it/s, loss=1.04]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 19.68it/s, accuracy=0.734]
# Epoch 12
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.28it/s, loss=1.03]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.65it/s, accuracy=0.734]
# Epoch 13
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.24it/s, loss=1.03]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.21it/s, accuracy=0.738]
# Epoch 14
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.90it/s, loss=1.02]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.79it/s, accuracy=0.748]
# Epoch 15
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.00it/s, loss=1.02]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 23.07it/s, accuracy=0.745]
# Epoch 16
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.06it/s, loss=1.02]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.55it/s, accuracy=0.727]
# Epoch 17
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.87it/s, loss=1.01]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.90it/s, accuracy=0.742]
# Epoch 18
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.95it/s, loss=1.01]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.62it/s, accuracy=0.75]
# Epoch 19
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.02it/s, loss=1]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.53it/s, accuracy=0.729]
# Epoch 20
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.77it/s, loss=1]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 22.55it/s, accuracy=0.744]
# Epoch 21
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.04it/s, loss=1]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 21.17it/s, accuracy=0.762]
# Ding ding ding! We found a new best model!
# Epoch 22
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.92it/s, loss=1]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.72it/s, accuracy=0.733]
# Epoch 23
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.83it/s, loss=0.997]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.27it/s, accuracy=0.755]
# Epoch 24
# Training: 100%|██████████| 500/500 [00:34<00:00, 14.30it/s, loss=0.996]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 18.91it/s, accuracy=0.79]
# Ding ding ding! We found a new best model!
# Epoch 25
# Training: 100%|██████████| 500/500 [00:34<00:00, 14.29it/s, loss=0.993]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 18.78it/s, accuracy=0.787]
# Epoch 26
# Training: 100%|██████████| 500/500 [00:35<00:00, 13.96it/s, loss=0.991]
# Validation: 100%|██████████| 100/100 [00:05<00:00, 18.56it/s, accuracy=0.747]
# Epoch 27
# Training: 100%|██████████| 500/500 [00:34<00:00, 14.29it/s, loss=0.987]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 20.38it/s, accuracy=0.774]
# Epoch 28
# Training: 100%|██████████| 500/500 [00:35<00:00, 14.24it/s, loss=0.987]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 21.73it/s, accuracy=0.756]
# Epoch 29
# Training: 100%|██████████| 500/500 [00:36<00:00, 13.87it/s, loss=0.988]
# Validation: 100%|██████████| 100/100 [00:04<00:00, 21.70it/s, accuracy=0.771]

# %%
# PATH = '/content/drive/MyDrive/PatternRecognition-main/ML/Proto/5shot_5way_BanglaPrototypicalNetworks_BanglaLekha_Isolated.pth'
# few_shot_classifier.load_state_dict(torch.load(PATH, map_location=torch.device('cpu')))

# %%
PATH = '/content/drive/MyDrive/PatternRecognition-main/ML/Proto/real_1shot_5way_BanglaPrototypicalNetworks_BanglaLekha_Final.pth'
few_shot_classifier.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Evaluation**

# %%
n_test_tasks = 100

test_set.get_labels = lambda: [
    instance[1] for instance in test_set
]

test_sampler = TaskSampler(
    test_set, n_way=n_way, n_shot=n_shot, n_query=n_query, n_tasks=n_test_tasks
)
test_loader = DataLoader(
    test_set,
    batch_sampler=test_sampler,
    num_workers=n_workers,
    pin_memory=True,
    collate_fn=test_sampler.episodic_collate_fn,
)

# %%
from easyfsl.utils import evaluate
accuracy = evaluate(few_shot_classifier, test_loader, device=DEVICE)
print(f"Average accuracy : {(100 * accuracy):.2f} %")
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 22.02it/s, accuracy=0.775]
# Average accuracy : 77.54 %

# %%
from sklearn.metrics import precision_recall_fscore_support
import torch


def evaluate_with_metrics(model, loader, device):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for _, (support_images, support_labels, query_images, query_labels, _) in enumerate(loader):
            model.process_support_set(support_images.to(device), support_labels.to(device))
            outputs = model(query_images.to(device))
            _, preds = torch.max(outputs, 1)
            all_labels.extend(query_labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    precision, recall, f1_score, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
    return precision, recall, f1_score

# %%
precision, recall, f1_score = evaluate_with_metrics(few_shot_classifier, test_loader, DEVICE)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")
# Out:
# Precision: 0.76
# Recall: 0.76
# F1 Score: 0.76

# %%
def predict_image_with_support_set(query_image_path):
    # Load and transform the query image
    query_image = Image.open(query_image_path).convert('RGB')
    query_image_tensor = image_transforms(query_image).unsqueeze(0)  # Add batch dimension

    # Set the model in evaluation mode
    few_shot_classifier.eval()

    # Use the model to predict
    with torch.no_grad():
        few_shot_classifier.process_support_set(support_images_tensor.to(DEVICE), support_labels_tensor.to(DEVICE))
        outputs = few_shot_classifier(query_image_tensor.to(DEVICE))

    probabilities = torch.softmax(outputs, dim=1)
    predicted_label_idx = probabilities.argmax(1).item()
    predicted_label = support_labels[predicted_label_idx] + 1  # Adjust label to match original range

    return predicted_label



import torch
from torchvision import transforms
from PIL import Image
import os


label_to_bengali = {
    1: "অ",
    2: "আ",
    3: "ই",
    4: "ঈ",
    5: "উ",
    6: "ঊ",
    7: "ঋ",
    8: "এ",
    9: "ঐ",
    10: "ও",
    11: "ঔ",
    12: "ক",
    13: "খ",
    14: "গ",
    15: "ঘ",
    16: "ঙ",
    17: "চ",
    18: "ছ",
    19: "জ",
    20: "ঝ",
    21: "ঞ",
    22: "ট",
    23: "ঠ",
    24: "ড",
    25: "ঢ",
    26: "ণ",
    27: "ত",
    28: "থ",
    29: "দ",
    30: "ধ",
    31: "ন",
    32: "প",
    33: "ফ",
    34: "ব",
    35: "ভ",
    36: "ম",
    37: "য",
    38: "র",
    39: "ল",
    40: "শ",
    41: "ষ",
    42: "স",
    43: "হ",
    44: "ড়",
    45: "ঢ়",
    46: "য়",
    47: "ৎ",
    48: "ং",
    49: "ঃ",
    50: "ঁ",
    51: "০",
    52: "১",
    53: "২",
    54: "৩",
    55: "৪",
    56: "৫",
    57: "৬",
    58: "৭",
    59: "৮",
    60: "৯",
}


# Function to print the Bengali character for a given label
def print_bengali_character(label):
    character = label_to_bengali.get(label, "Unknown label")
    print(character)


# Define the image preprocessing
image_transforms = transforms.Compose([
    transforms.Resize((84, 84)),  # Resize the image to what the model expects
    transforms.ToTensor(),        # Convert the image to a tensor
])

# Define the root directory of your support images
root_dir = '/content/data/BanglaLekha_Isolated_mod/Test/'

# Generate support set
support_images = []
support_labels = []

# Assuming each class directory contains images for that class
for label in range(1, 12):  # Labels from 1 to 60
    class_dir = os.path.join(root_dir, str(label))
    if not os.path.exists(class_dir):
        continue  # Skip if the class directory doesn't exist

    # List all images in the class directory
    img_files = [f for f in os.listdir(class_dir) if f.endswith('.png')]
    for img_file in img_files[:1]:  # Take only the first image for simplicity; adjust as needed
        img_path = os.path.join(class_dir, img_file)
        image = Image.open(img_path).convert('RGB')
        support_images.append(image_transforms(image))
        support_labels.append(label - 1)  # Adjust label to start from 0

# Convert lists to tensors
support_images_tensor = torch.stack(support_images)
support_labels_tensor = torch.tensor(support_labels)

query_image_path = '/content/mota_dho.jpg'
predicted_label = predict_image_with_support_set(query_image_path)
print("Predicted label: ")
print_bengali_character(predicted_label)
# Out:
# Predicted label:
# ষ
